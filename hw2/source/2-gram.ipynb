# %%
import os
import numpy as np
from collections import defaultdict
import xml.etree.ElementTree as ET
from collections import Counter

# filename
DATA_DIR = '../data'
TRAIN_ANS_FILE = os.path.join(DATA_DIR, 'ans_train.csv')
QUERY_TRAIN_FILE = os.path.join(DATA_DIR, 'query-train.xml')
QUERY_TEST_FILE = os.path.join(DATA_DIR, 'query-test.xml')
FILE_LIST = os.path.join(DATA_DIR, 'file-list')
INV_FILE = os.path.join(DATA_DIR, 'inverted-file')
VOCAB_FILE = os.path.join(DATA_DIR, 'vocab.all')
OUTPUT_FILE = 'output.csv'

# building maps
docname2id = dict()
with open(FILE_LIST, 'r') as f:
    for idx, line in enumerate(f):
        docname2id[line.strip()] = idx
id2docname = {y:x for x, y in docname2id.items()}

word2id = dict()
with open(VOCAB_FILE, 'r') as f:
    f.readline()
    for idx, line in enumerate(f, 1):
        word2id[line.strip()] = idx

word_freq = dict()
gram_freq = dict()
gram2id = dict()
with open(INV_FILE, 'r') as f:
    idx = 0
    while True:
        line = f.readline().strip()
        if not line:
            break
        id_1, id_2, doc_count = [int(i) for i in line.split(' ')]
        doc_records = defaultdict(int)
        for i in range(doc_count):
            doc_id, freq = [int(i) for i in f.readline().strip().split(' ')]
            doc_records[doc_id] = freq
        if id_2 == -1:
            word_freq[(id_1)] = doc_records
#         else:
#             gram_freq[(id_1, id_2)] = doc_records
#             gram2id[(id_1, id_2)] = idx
#             idx += 1
        gram_freq[(id_1, id_2)] = doc_records
        gram2id[(id_1, id_2)] = idx
        idx += 1

# %%
# doc2len = defaultdict(int)
# for word_id, records in word_freq.items():
#     for doc_id, freq in records.items():
#         doc2len[doc_id] += freq
# avdl = sum([length for _, length in doc2len.items()]) / len(doc2len)
doc2len = defaultdict(int)
for docname, idx in docname2id.items():
    doc2len[idx] = os.path.getsize(os.path.join(DATA_DIR, docname))
avdl = sum([length for _, length in doc2len.items()]) / len(doc2len)

# %%
tree = ET.ElementTree(file=QUERY_TRAIN_FILE)
root = tree.getroot()

query_num = len(root)
word_num = len(gram2id) + 1
doc_num = len(docname2id)

# %%
from scipy.sparse import dok_matrix

def two_char_to_gramid(c1, c2):
    try:
        c1 = word2id[c1]
        if c2 is None:
            c2 = -1
        else:
            c2 = word2id[c2]
        return gram2id[(c1, c2)]
    except:
        return 0

def generate_candidates_weight(k_1=1.5, b=0.75):
    weight = dok_matrix((doc_num, word_num), dtype=np.float32)
    for idx, (gram, records) in enumerate(gram_freq.items(), 1):
        word_id = gram2id[gram]
        IDF = np.log((doc_num - len(records) + 0.5) / (len(records) + 0.5))
        for doc_id, freq in records.items():
            TF = (k_1 + 1) * freq / (freq + k_1 * (1 - b + b * doc2len[doc_id] / avdl))
            weight[doc_id, word_id] = TF * IDF
        if idx % 1000 == 0:
            print('Has indexed %d grams' % idx)
    return weight

def generate_queries_weight(ka=100):
#     queries = dok_matrix((query_num, word_num), dtype=np.float32)
    queries = np.zeros((query_num, word_num))
    for query_id, child in enumerate(root):
        query = child[4].text.strip('\n。 ').split('、')
        grams = []
        for w in query:
            if len(w) == 1:
                grams.append(two_char_to_gramid(w, None))
                break
            else:
                for c in w:
                    grams.append(two_char_to_gramid(c, None))
                for ci, cj in zip(w[:-1], w[1:]):
                    grams.append(two_char_to_gramid(ci, cj))
#         print(grams)
        for word, freq in Counter(grams).items():
            if not word:
                continue
            TF = (ka + 1) * freq / (freq + ka)
            queries[query_id, word] = TF
    return queries

# %%
def MAP(top100):
    AP = []
    with open(TRAIN_ANS_FILE, 'r') as f:
        f.readline()
        for line, rank in zip(f, top100):
            idx, answer = line.strip().split(',')
            answer = set(answer.split())
            rank = [(id2docname[i].split('/')[-1].lower()) for i in rank]
            hit = 0
            P = []
            for rank_i, rank in enumerate(rank, 1):
                if rank in answer:
                    hit += 1
                    P.append(hit / rank_i)
            AP.append(sum(P) / len(P))
    return sum(AP) / len(AP)

# %%
candidates = generate_candidates_weight(k_1=1.6, b=0.75)

# %%
queries = generate_queries_weight(ka=5.0)

# %%
# ret = np.matmul(queries, np.transpose(candidates)).argsort(axis=1)[:, ::-1][:, :100]
scores = candidates.dot(np.transpose(queries))
# print('k_1: %.2f, ka: %.2f, MPA: %.8f' % (k_1, ka, MAP(ret)))

# %%
scores = np.transpose(scores)

# %%
ret = scores.argsort(axis=1)[:, ::-1][:, :100]
MAP(ret)

# %%
for k_1 in [1, 1.2, 1.4, 1.6, 1.8, 2.0]:
    for ka in [0, 5, 10, 50, 100, 300, 500, 1000]:
        candidates = generate_candidates_weight(k_1, b=0.75)
        queries = generate_queries_weight(ka)
        ret = np.matmul(queries, np.transpose(candidates)).argsort(axis=1)[:, ::-1][:, :100]
        print('k_1: %.2f, ka: %.2f, MPA: %.8f' % (k_1, ka, MAP(ret)))

# %%
# Testing Part
tree = ET.ElementTree(file=QUERY_TEST_FILE)
root = tree.getroot()
query_num = len(root)

candidates = generate_candidates_weight(k_1=1.6, b=0.75)
queries = generate_queries_weight(ka=5.0)
ret = (np.transpose(candidates.dot(np.transpose(queries)))).argsort(axis=1)[:, ::-1][:, :100]

with open(OUTPUT_FILE, 'w+') as f:
    print('query_id,retrieved_docs', file=f)
    for idx, result in enumerate(ret, 11):
        print(str(idx).zfill(3), ' '.join([(id2docname[i].split('/')[-1].lower()) for i in result]), sep=',', file=f)
# Out:
# Has indexed 1000 grams
# Has indexed 2000 grams
# Has indexed 3000 grams
# Has indexed 4000 grams
# Has indexed 5000 grams
# Has indexed 6000 grams
# Has indexed 7000 grams
# Has indexed 8000 grams
# Has indexed 9000 grams
# Has indexed 10000 grams
# Has indexed 11000 grams
# Has indexed 12000 grams
# Has indexed 13000 grams
# Has indexed 14000 grams
# Has indexed 15000 grams
# Has indexed 16000 grams
# Has indexed 17000 grams
# Has indexed 18000 grams
# Has indexed 19000 grams
# Has indexed 20000 grams
# Has indexed 21000 grams
# Has indexed 22000 grams
# Has indexed 23000 grams
# Has indexed 24000 grams
# Has indexed 25000 grams
# Has indexed 26000 grams
# Has indexed 27000 grams
# Has indexed 28000 grams
# Has indexed 29000 grams
# Has indexed 30000 grams
# Has indexed 31000 grams
# Has indexed 32000 grams
# Has indexed 33000 grams
# Has indexed 34000 grams
# Has indexed 35000 grams
# Has indexed 36000 grams
# Has indexed 37000 grams
# Has indexed 38000 grams
# Has indexed 39000 grams
# Has indexed 40000 grams
# Has indexed 41000 grams
# Has indexed 42000 grams
# Has indexed 43000 grams
# Has indexed 44000 grams
# Has indexed 45000 grams
# Has indexed 46000 grams
# Has indexed 47000 grams
# Has indexed 48000 grams
# Has indexed 49000 grams
# Has indexed 50000 grams
# Has indexed 51000 grams
# Has indexed 52000 grams
# Has indexed 53000 grams
# Has indexed 54000 grams
# Has indexed 55000 grams
# Has indexed 56000 grams
# Has indexed 57000 grams
# Has indexed 58000 grams
# Has indexed 59000 grams
# Has indexed 60000 grams
# Has indexed 61000 grams
# Has indexed 62000 grams
# Has indexed 63000 grams
# Has indexed 64000 grams
# Has indexed 65000 grams
# Has indexed 66000 grams
# Has indexed 67000 grams
# Has indexed 68000 grams
# Has indexed 69000 grams
# Has indexed 70000 grams
# Has indexed 71000 grams
# Has indexed 72000 grams
# Has indexed 73000 grams
# Has indexed 74000 grams
# Has indexed 75000 grams
# Has indexed 76000 grams
# Has indexed 77000 grams
# Has indexed 78000 grams
# Has indexed 79000 grams
# Has indexed 80000 grams
# Has indexed 81000 grams
# Has indexed 82000 grams
# Has indexed 83000 grams
# Has indexed 84000 grams
# Has indexed 85000 grams
# Has indexed 86000 grams
# Has indexed 87000 grams
# Has indexed 88000 grams
# Has indexed 89000 grams
# Has indexed 90000 grams
# Has indexed 91000 grams
# Has indexed 92000 grams
# Has indexed 93000 grams
# Has indexed 94000 grams
# Has indexed 95000 grams
# Has indexed 96000 grams
# Has indexed 97000 grams
# Has indexed 98000 grams
# Has indexed 99000 grams
# Has indexed 100000 grams
# Has indexed 101000 grams
# Has indexed 102000 grams
# Has indexed 103000 grams
# Has indexed 104000 grams
# Has indexed 105000 grams
# Has indexed 106000 grams
# Has indexed 107000 grams
# Has indexed 108000 grams
# Has indexed 109000 grams
# Has indexed 110000 grams
# Has indexed 111000 grams
# Has indexed 112000 grams
# Has indexed 113000 grams
# Has indexed 114000 grams
# Has indexed 115000 grams
# Has indexed 116000 grams
# Has indexed 117000 grams
# Has indexed 118000 grams
# Has indexed 119000 grams
# Has indexed 120000 grams
# Has indexed 121000 grams
# Has indexed 122000 grams
# Has indexed 123000 grams
# Has indexed 124000 grams
# Has indexed 125000 grams
# Has indexed 126000 grams
# Has indexed 127000 grams
# Has indexed 128000 grams
# Has indexed 129000 grams
# Has indexed 130000 grams
# Has indexed 131000 grams
# Has indexed 132000 grams
# Has indexed 133000 grams
# Has indexed 134000 grams
# Has indexed 135000 grams
# Has indexed 136000 grams
# Has indexed 137000 grams
# Has indexed 138000 grams
# Has indexed 139000 grams
# Has indexed 140000 grams
# Has indexed 141000 grams
# Has indexed 142000 grams
# Has indexed 143000 grams
# Has indexed 144000 grams
# Has indexed 145000 grams
# Has indexed 146000 grams
# Has indexed 147000 grams
# Has indexed 148000 grams
# Has indexed 149000 grams
# Has indexed 150000 grams
# Has indexed 151000 grams
# Has indexed 152000 grams
# Has indexed 153000 grams
# Has indexed 154000 grams
# Has indexed 155000 grams
# Has indexed 156000 grams
# Has indexed 157000 grams
# Has indexed 158000 grams
# Has indexed 159000 grams
# Has indexed 160000 grams
# Has indexed 161000 grams
# Has indexed 162000 grams
# Has indexed 163000 grams
# Has indexed 164000 grams
# Has indexed 165000 grams
# Has indexed 166000 grams
# Has indexed 167000 grams
# Has indexed 168000 grams
# Has indexed 169000 grams
# Has indexed 170000 grams
# Has indexed 171000 grams
# Has indexed 172000 grams
# Has indexed 173000 grams
# Has indexed 174000 grams
# Has indexed 175000 grams
# Has indexed 176000 grams
# Has indexed 177000 grams
# Has indexed 178000 grams
# Has indexed 179000 grams
# Has indexed 180000 grams
# Has indexed 181000 grams
# Has indexed 182000 grams
# Has indexed 183000 grams
# Has indexed 184000 grams
# Has indexed 185000 grams
# Has indexed 186000 grams
# Has indexed 187000 grams
# Has indexed 188000 grams
# Has indexed 189000 grams
# Has indexed 190000 grams
# Has indexed 191000 grams
# Has indexed 192000 grams
# Has indexed 193000 grams
# Has indexed 194000 grams
# Has indexed 195000 grams
# Has indexed 196000 grams
# Has indexed 197000 grams
# Has indexed 198000 grams
# Has indexed 199000 grams
# Has indexed 200000 grams
# Has indexed 201000 grams
# Has indexed 202000 grams
# Has indexed 203000 grams
# Has indexed 204000 grams
# Has indexed 205000 grams
# Has indexed 206000 grams
# Has indexed 207000 grams
# Has indexed 208000 grams
# Has indexed 209000 grams
# Has indexed 210000 grams
# Has indexed 211000 grams
# Has indexed 212000 grams
# Has indexed 213000 grams
# Has indexed 214000 grams
# Has indexed 215000 grams
# Has indexed 216000 grams
# Has indexed 217000 grams
# Has indexed 218000 grams
# Has indexed 219000 grams
# Has indexed 220000 grams
# Has indexed 221000 grams
# Has indexed 222000 grams
# Has indexed 223000 grams
# Has indexed 224000 grams
# Has indexed 225000 grams
# Has indexed 226000 grams
# Has indexed 227000 grams
# Has indexed 228000 grams
# Has indexed 229000 grams
# Has indexed 230000 grams
# Has indexed 231000 grams
# Has indexed 232000 grams
# Has indexed 233000 grams
# Has indexed 234000 grams
# Has indexed 235000 grams
# Has indexed 236000 grams
# Has indexed 237000 grams
# Has indexed 238000 grams
# Has indexed 239000 grams
# Has indexed 240000 grams
# Has indexed 241000 grams
# Has indexed 242000 grams
# Has indexed 243000 grams
# Has indexed 244000 grams
# Has indexed 245000 grams
# Has indexed 246000 grams
# Has indexed 247000 grams
# Has indexed 248000 grams
# Has indexed 249000 grams
# Has indexed 250000 grams
# Has indexed 251000 grams
# Has indexed 252000 grams
# Has indexed 253000 grams
# Has indexed 254000 grams
# Has indexed 255000 grams
# Has indexed 256000 grams
# Has indexed 257000 grams
# Has indexed 258000 grams
# Has indexed 259000 grams
# Has indexed 260000 grams
# Has indexed 261000 grams
# Has indexed 262000 grams
# Has indexed 263000 grams
# Has indexed 264000 grams
# Has indexed 265000 grams
# Has indexed 266000 grams
# Has indexed 267000 grams
# Has indexed 268000 grams
# Has indexed 269000 grams
# Has indexed 270000 grams
# Has indexed 271000 grams
# Has indexed 272000 grams
# Has indexed 273000 grams
# Has indexed 274000 grams
# Has indexed 275000 grams
# Has indexed 276000 grams
# Has indexed 277000 grams
# Has indexed 278000 grams
# Has indexed 279000 grams
# Has indexed 280000 grams
# Has indexed 281000 grams
# Has indexed 282000 grams
# Has indexed 283000 grams
# Has indexed 284000 grams
# Has indexed 285000 grams
# Has indexed 286000 grams
# Has indexed 287000 grams
# Has indexed 288000 grams
# Has indexed 289000 grams
# Has indexed 290000 grams
# Has indexed 291000 grams
# Has indexed 292000 grams
# Has indexed 293000 grams
# Has indexed 294000 grams
# Has indexed 295000 grams
# Has indexed 296000 grams
# Has indexed 297000 grams
# Has indexed 298000 grams
# Has indexed 299000 grams
# Has indexed 300000 grams
# Has indexed 301000 grams
# Has indexed 302000 grams
# Has indexed 303000 grams
# Has indexed 304000 grams
# Has indexed 305000 grams
# Has indexed 306000 grams
# Has indexed 307000 grams
# Has indexed 308000 grams
# Has indexed 309000 grams
# Has indexed 310000 grams
# Has indexed 311000 grams
# Has indexed 312000 grams
# Has indexed 313000 grams
# Has indexed 314000 grams
# Has indexed 315000 grams
# Has indexed 316000 grams
# Has indexed 317000 grams
# Has indexed 318000 grams
# Has indexed 319000 grams
# Has indexed 320000 grams
# Has indexed 321000 grams
# Has indexed 322000 grams
# Has indexed 323000 grams
# Has indexed 324000 grams
# Has indexed 325000 grams
# Has indexed 326000 grams
# Has indexed 327000 grams
# Has indexed 328000 grams
# Has indexed 329000 grams
# Has indexed 330000 grams
# Has indexed 331000 grams
# Has indexed 332000 grams
# Has indexed 333000 grams
# Has indexed 334000 grams
# Has indexed 335000 grams
# Has indexed 336000 grams
# Has indexed 337000 grams
# Has indexed 338000 grams
# Has indexed 339000 grams
# Has indexed 340000 grams
# Has indexed 341000 grams
# Has indexed 342000 grams
# Has indexed 343000 grams
# Has indexed 344000 grams
# Has indexed 345000 grams
# Has indexed 346000 grams
# Has indexed 347000 grams
# Has indexed 348000 grams
# Has indexed 349000 grams
# Has indexed 350000 grams
# Has indexed 351000 grams
# Has indexed 352000 grams
# Has indexed 353000 grams
# Has indexed 354000 grams
# Has indexed 355000 grams
# Has indexed 356000 grams
# Has indexed 357000 grams
# Has indexed 358000 grams
# Has indexed 359000 grams
# Has indexed 360000 grams
# Has indexed 361000 grams
# Has indexed 362000 grams
# Has indexed 363000 grams
# Has indexed 364000 grams
# Has indexed 365000 grams
# Has indexed 366000 grams
# Has indexed 367000 grams
# Has indexed 368000 grams
# Has indexed 369000 grams
# Has indexed 370000 grams
# Has indexed 371000 grams
# Has indexed 372000 grams
# Has indexed 373000 grams
# Has indexed 374000 grams
# Has indexed 375000 grams
# Has indexed 376000 grams
# Has indexed 377000 grams
# Has indexed 378000 grams
# Has indexed 379000 grams
# Has indexed 380000 grams
# Has indexed 381000 grams
# Has indexed 382000 grams
# Has indexed 383000 grams
# Has indexed 384000 grams
# Has indexed 385000 grams
# Has indexed 386000 grams
# Has indexed 387000 grams
# Has indexed 388000 grams
# Has indexed 389000 grams
# Has indexed 390000 grams
# Has indexed 391000 grams
# Has indexed 392000 grams
# Has indexed 393000 grams
# Has indexed 394000 grams
# Has indexed 395000 grams
# Has indexed 396000 grams
# Has indexed 397000 grams
# Has indexed 398000 grams
# Has indexed 399000 grams
# Has indexed 400000 grams
# Has indexed 401000 grams
# Has indexed 402000 grams
# Has indexed 403000 grams
# Has indexed 404000 grams
# Has indexed 405000 grams
# Has indexed 406000 grams
# Has indexed 407000 grams
# Has indexed 408000 grams
# Has indexed 409000 grams
# Has indexed 410000 grams
# Has indexed 411000 grams
# Has indexed 412000 grams
# Has indexed 413000 grams
# Has indexed 414000 grams
# Has indexed 415000 grams
# Has indexed 416000 grams
# Has indexed 417000 grams
# Has indexed 418000 grams
# Has indexed 419000 grams
# Has indexed 420000 grams
# Has indexed 421000 grams
# Has indexed 422000 grams
# Has indexed 423000 grams
# Has indexed 424000 grams
# Has indexed 425000 grams
# Has indexed 426000 grams
# Has indexed 427000 grams
# Has indexed 428000 grams
# Has indexed 429000 grams
# Has indexed 430000 grams
# Has indexed 431000 grams
# Has indexed 432000 grams
# Has indexed 433000 grams
# Has indexed 434000 grams
# Has indexed 435000 grams
# Has indexed 436000 grams
# Has indexed 437000 grams
# Has indexed 438000 grams
# Has indexed 439000 grams
# Has indexed 440000 grams
# Has indexed 441000 grams
# Has indexed 442000 grams
# Has indexed 443000 grams
# Has indexed 444000 grams
# Has indexed 445000 grams
# Has indexed 446000 grams
# Has indexed 447000 grams
# Has indexed 448000 grams
# Has indexed 449000 grams
# Has indexed 450000 grams
# Has indexed 451000 grams
# Has indexed 452000 grams
# Has indexed 453000 grams
# Has indexed 454000 grams
# Has indexed 455000 grams
# Has indexed 456000 grams
# Has indexed 457000 grams
# Has indexed 458000 grams
# Has indexed 459000 grams
# Has indexed 460000 grams
# Has indexed 461000 grams
# Has indexed 462000 grams
# Has indexed 463000 grams
# Has indexed 464000 grams
# Has indexed 465000 grams
# Has indexed 466000 grams
# Has indexed 467000 grams
# Has indexed 468000 grams
# Has indexed 469000 grams
# Has indexed 470000 grams
# Has indexed 471000 grams
# Has indexed 472000 grams
# Has indexed 473000 grams
# Has indexed 474000 grams
# Has indexed 475000 grams
# Has indexed 476000 grams
# Has indexed 477000 grams
# Has indexed 478000 grams
# Has indexed 479000 grams
# Has indexed 480000 grams
# Has indexed 481000 grams
# Has indexed 482000 grams
# Has indexed 483000 grams
# Has indexed 484000 grams
# Has indexed 485000 grams
# Has indexed 486000 grams
# Has indexed 487000 grams
# Has indexed 488000 grams
# Has indexed 489000 grams
# Has indexed 490000 grams
# Has indexed 491000 grams
# Has indexed 492000 grams
# Has indexed 493000 grams
# Has indexed 494000 grams
# Has indexed 495000 grams
# Has indexed 496000 grams
# Has indexed 497000 grams
# Has indexed 498000 grams
# Has indexed 499000 grams
# Has indexed 500000 grams
# Has indexed 501000 grams
# Has indexed 502000 grams
# Has indexed 503000 grams
# Has indexed 504000 grams
# Has indexed 505000 grams
# Has indexed 506000 grams
# Has indexed 507000 grams
# Has indexed 508000 grams
# Has indexed 509000 grams
# Has indexed 510000 grams
# Has indexed 511000 grams
# Has indexed 512000 grams
# Has indexed 513000 grams
# Has indexed 514000 grams
# Has indexed 515000 grams
# Has indexed 516000 grams
# Has indexed 517000 grams
# Has indexed 518000 grams
# Has indexed 519000 grams
# Has indexed 520000 grams
# Has indexed 521000 grams
# Has indexed 522000 grams
# Has indexed 523000 grams
# Has indexed 524000 grams
# Has indexed 525000 grams
# Has indexed 526000 grams
# Has indexed 527000 grams
# Has indexed 528000 grams
# Has indexed 529000 grams
# Has indexed 530000 grams
# Has indexed 531000 grams
# Has indexed 532000 grams
# Has indexed 533000 grams
# Has indexed 534000 grams
# Has indexed 535000 grams
# Has indexed 536000 grams
# Has indexed 537000 grams
# Has indexed 538000 grams
# Has indexed 539000 grams
# Has indexed 540000 grams
# Has indexed 541000 grams
# Has indexed 542000 grams
# Has indexed 543000 grams
# Has indexed 544000 grams
# Has indexed 545000 grams
# Has indexed 546000 grams
# Has indexed 547000 grams
# Has indexed 548000 grams
# Has indexed 549000 grams
# Has indexed 550000 grams
# Has indexed 551000 grams
# Has indexed 552000 grams
# Has indexed 553000 grams
# Has indexed 554000 grams
# Has indexed 555000 grams
# Has indexed 556000 grams
# Has indexed 557000 grams
# Has indexed 558000 grams
# Has indexed 559000 grams
# Has indexed 560000 grams
# Has indexed 561000 grams
# Has indexed 562000 grams
# Has indexed 563000 grams
# Has indexed 564000 grams
# Has indexed 565000 grams
# Has indexed 566000 grams
# Has indexed 567000 grams
# Has indexed 568000 grams
# Has indexed 569000 grams
# Has indexed 570000 grams
# Has indexed 571000 grams
# Has indexed 572000 grams
# Has indexed 573000 grams
# Has indexed 574000 grams
# Has indexed 575000 grams
# Has indexed 576000 grams
# Has indexed 577000 grams
# Has indexed 578000 grams
# Has indexed 579000 grams
# Has indexed 580000 grams
# Has indexed 581000 grams
# Has indexed 582000 grams
# Has indexed 583000 grams
# Has indexed 584000 grams
# Has indexed 585000 grams
# Has indexed 586000 grams
# Has indexed 587000 grams
# Has indexed 588000 grams
# Has indexed 589000 grams
# Has indexed 590000 grams
# Has indexed 591000 grams
# Has indexed 592000 grams
# Has indexed 593000 grams
# Has indexed 594000 grams
# Has indexed 595000 grams
# Has indexed 596000 grams
# Has indexed 597000 grams
# Has indexed 598000 grams
# Has indexed 599000 grams
# Has indexed 600000 grams
# Has indexed 601000 grams
# Has indexed 602000 grams
# Has indexed 603000 grams
# Has indexed 604000 grams
# Has indexed 605000 grams
# Has indexed 606000 grams
# Has indexed 607000 grams
# Has indexed 608000 grams
# Has indexed 609000 grams
# Has indexed 610000 grams
# Has indexed 611000 grams
# Has indexed 612000 grams
# Has indexed 613000 grams
# Has indexed 614000 grams
# Has indexed 615000 grams
# Has indexed 616000 grams
# Has indexed 617000 grams
# Has indexed 618000 grams
# Has indexed 619000 grams
# Has indexed 620000 grams
# Has indexed 621000 grams
# Has indexed 622000 grams
# Has indexed 623000 grams
# Has indexed 624000 grams
# Has indexed 625000 grams
# Has indexed 626000 grams
# Has indexed 627000 grams
# Has indexed 628000 grams
# Has indexed 629000 grams
# Has indexed 630000 grams
# Has indexed 631000 grams
# Has indexed 632000 grams
# Has indexed 633000 grams
# Has indexed 634000 grams
# Has indexed 635000 grams
# Has indexed 636000 grams
# Has indexed 637000 grams
# Has indexed 638000 grams
# Has indexed 639000 grams
# Has indexed 640000 grams
# Has indexed 641000 grams
# Has indexed 642000 grams
# Has indexed 643000 grams
# Has indexed 644000 grams
# Has indexed 645000 grams
# Has indexed 646000 grams
# Has indexed 647000 grams
# Has indexed 648000 grams
# Has indexed 649000 grams
# Has indexed 650000 grams
# Has indexed 651000 grams
# Has indexed 652000 grams
# Has indexed 653000 grams
# Has indexed 654000 grams
# Has indexed 655000 grams
# Has indexed 656000 grams
# Has indexed 657000 grams
# Has indexed 658000 grams
# Has indexed 659000 grams
# Has indexed 660000 grams
# Has indexed 661000 grams
# Has indexed 662000 grams
# Has indexed 663000 grams
# Has indexed 664000 grams
# Has indexed 665000 grams
# Has indexed 666000 grams
# Has indexed 667000 grams
# Has indexed 668000 grams
# Has indexed 669000 grams
# Has indexed 670000 grams
# Has indexed 671000 grams
# Has indexed 672000 grams
# Has indexed 673000 grams
# Has indexed 674000 grams
# Has indexed 675000 grams
# Has indexed 676000 grams
# Has indexed 677000 grams
# Has indexed 678000 grams
# Has indexed 679000 grams
# Has indexed 680000 grams
# Has indexed 681000 grams
# Has indexed 682000 grams
# Has indexed 683000 grams
# Has indexed 684000 grams
# Has indexed 685000 grams
# Has indexed 686000 grams
# Has indexed 687000 grams
# Has indexed 688000 grams
# Has indexed 689000 grams
# Has indexed 690000 grams
# Has indexed 691000 grams
# Has indexed 692000 grams
# Has indexed 693000 grams
# Has indexed 694000 grams
# Has indexed 695000 grams
# Has indexed 696000 grams
# Has indexed 697000 grams
# Has indexed 698000 grams
# Has indexed 699000 grams
# Has indexed 700000 grams
# Has indexed 701000 grams
# Has indexed 702000 grams
# Has indexed 703000 grams
# Has indexed 704000 grams
# Has indexed 705000 grams
# Has indexed 706000 grams
# Has indexed 707000 grams
# Has indexed 708000 grams
# Has indexed 709000 grams
# Has indexed 710000 grams
# Has indexed 711000 grams
# Has indexed 712000 grams
# Has indexed 713000 grams
# Has indexed 714000 grams
# Has indexed 715000 grams
# Has indexed 716000 grams
# Has indexed 717000 grams
# Has indexed 718000 grams
# Has indexed 719000 grams
# Has indexed 720000 grams
# Has indexed 721000 grams
# Has indexed 722000 grams
# Has indexed 723000 grams
# Has indexed 724000 grams
# Has indexed 725000 grams
# Has indexed 726000 grams
# Has indexed 727000 grams
# Has indexed 728000 grams
# Has indexed 729000 grams
# Has indexed 730000 grams
# Has indexed 731000 grams
# Has indexed 732000 grams
# Has indexed 733000 grams
# Has indexed 734000 grams
# Has indexed 735000 grams
# Has indexed 736000 grams
# Has indexed 737000 grams
# Has indexed 738000 grams
# Has indexed 739000 grams
# Has indexed 740000 grams
# Has indexed 741000 grams
# Has indexed 742000 grams
# Has indexed 743000 grams
# Has indexed 744000 grams
# Has indexed 745000 grams
# Has indexed 746000 grams
# Has indexed 747000 grams
# Has indexed 748000 grams
# Has indexed 749000 grams
# Has indexed 750000 grams
# Has indexed 751000 grams
# Has indexed 752000 grams
# Has indexed 753000 grams
# Has indexed 754000 grams
# Has indexed 755000 grams
# Has indexed 756000 grams
# Has indexed 757000 grams
# Has indexed 758000 grams
# Has indexed 759000 grams
# Has indexed 760000 grams
# Has indexed 761000 grams
# Has indexed 762000 grams
# Has indexed 763000 grams
# Has indexed 764000 grams
# Has indexed 765000 grams
# Has indexed 766000 grams
# Has indexed 767000 grams
# Has indexed 768000 grams
# Has indexed 769000 grams
# Has indexed 770000 grams
# Has indexed 771000 grams
# Has indexed 772000 grams
# Has indexed 773000 grams
# Has indexed 774000 grams
# Has indexed 775000 grams
# Has indexed 776000 grams
# Has indexed 777000 grams
# Has indexed 778000 grams
# Has indexed 779000 grams
# Has indexed 780000 grams
# Has indexed 781000 grams
# Has indexed 782000 grams
# Has indexed 783000 grams
# Has indexed 784000 grams
# Has indexed 785000 grams
# Has indexed 786000 grams
# Has indexed 787000 grams
# Has indexed 788000 grams
# Has indexed 789000 grams
# Has indexed 790000 grams
# Has indexed 791000 grams
# Has indexed 792000 grams
# Has indexed 793000 grams
# Has indexed 794000 grams
# Has indexed 795000 grams
# Has indexed 796000 grams
# Has indexed 797000 grams
# Has indexed 798000 grams
# Has indexed 799000 grams
# Has indexed 800000 grams
# Has indexed 801000 grams
# Has indexed 802000 grams
# Has indexed 803000 grams
# Has indexed 804000 grams
# Has indexed 805000 grams
# Has indexed 806000 grams
# Has indexed 807000 grams
# Has indexed 808000 grams
# Has indexed 809000 grams
# Has indexed 810000 grams
# Has indexed 811000 grams
# Has indexed 812000 grams
# Has indexed 813000 grams
# Has indexed 814000 grams
# Has indexed 815000 grams
# Has indexed 816000 grams
# Has indexed 817000 grams
# Has indexed 818000 grams
# Has indexed 819000 grams
# Has indexed 820000 grams
# Has indexed 821000 grams
# Has indexed 822000 grams
# Has indexed 823000 grams
# Has indexed 824000 grams
# Has indexed 825000 grams
# Has indexed 826000 grams
# Has indexed 827000 grams
# Has indexed 828000 grams
# Has indexed 829000 grams
# Has indexed 830000 grams
# Has indexed 831000 grams
# Has indexed 832000 grams
# Has indexed 833000 grams
# Has indexed 834000 grams
# Has indexed 835000 grams
# Has indexed 836000 grams
# Has indexed 837000 grams
# Has indexed 838000 grams
# Has indexed 839000 grams
# Has indexed 840000 grams
# Has indexed 841000 grams
# Has indexed 842000 grams
# Has indexed 843000 grams
# Has indexed 844000 grams
# Has indexed 845000 grams
# Has indexed 846000 grams
# Has indexed 847000 grams
# Has indexed 848000 grams
# Has indexed 849000 grams
# Has indexed 850000 grams
# Has indexed 851000 grams
# Has indexed 852000 grams
# Has indexed 853000 grams
# Has indexed 854000 grams
# Has indexed 855000 grams
# Has indexed 856000 grams
# Has indexed 857000 grams
# Has indexed 858000 grams
# Has indexed 859000 grams
# Has indexed 860000 grams
# Has indexed 861000 grams
# Has indexed 862000 grams
# Has indexed 863000 grams
# Has indexed 864000 grams
# Has indexed 865000 grams
# Has indexed 866000 grams
# Has indexed 867000 grams
# Has indexed 868000 grams
# Has indexed 869000 grams
# Has indexed 870000 grams
# Has indexed 871000 grams
# Has indexed 872000 grams
# Has indexed 873000 grams
# Has indexed 874000 grams
# Has indexed 875000 grams
# Has indexed 876000 grams
# Has indexed 877000 grams
# Has indexed 878000 grams
# Has indexed 879000 grams
# Has indexed 880000 grams
# Has indexed 881000 grams
# Has indexed 882000 grams
# Has indexed 883000 grams
# Has indexed 884000 grams
# Has indexed 885000 grams
# Has indexed 886000 grams
# Has indexed 887000 grams
# Has indexed 888000 grams
# Has indexed 889000 grams
# Has indexed 890000 grams
# Has indexed 891000 grams
# Has indexed 892000 grams
# Has indexed 893000 grams
# Has indexed 894000 grams
# Has indexed 895000 grams
# Has indexed 896000 grams
# Has indexed 897000 grams
# Has indexed 898000 grams
# Has indexed 899000 grams
# Has indexed 900000 grams
# Has indexed 901000 grams
# Has indexed 902000 grams
# Has indexed 903000 grams
# Has indexed 904000 grams
# Has indexed 905000 grams
# Has indexed 906000 grams
# Has indexed 907000 grams
# Has indexed 908000 grams
# Has indexed 909000 grams
# Has indexed 910000 grams
# Has indexed 911000 grams
# Has indexed 912000 grams
# Has indexed 913000 grams
# Has indexed 914000 grams
# Has indexed 915000 grams
# Has indexed 916000 grams
# Has indexed 917000 grams
# Has indexed 918000 grams
# Has indexed 919000 grams
# Has indexed 920000 grams
# Has indexed 921000 grams
# Has indexed 922000 grams
# Has indexed 923000 grams
# Has indexed 924000 grams
# Has indexed 925000 grams
# Has indexed 926000 grams
# Has indexed 927000 grams
# Has indexed 928000 grams
# Has indexed 929000 grams
# Has indexed 930000 grams
# Has indexed 931000 grams
# Has indexed 932000 grams
# Has indexed 933000 grams
# Has indexed 934000 grams
# Has indexed 935000 grams
# Has indexed 936000 grams
# Has indexed 937000 grams
# Has indexed 938000 grams
# Has indexed 939000 grams
# Has indexed 940000 grams
# Has indexed 941000 grams
# Has indexed 942000 grams
# Has indexed 943000 grams
# Has indexed 944000 grams
# Has indexed 945000 grams
# Has indexed 946000 grams
# Has indexed 947000 grams
# Has indexed 948000 grams
# Has indexed 949000 grams
# Has indexed 950000 grams
# Has indexed 951000 grams
# Has indexed 952000 grams
# Has indexed 953000 grams
# Has indexed 954000 grams
# Has indexed 955000 grams
# Has indexed 956000 grams
# Has indexed 957000 grams
# Has indexed 958000 grams
# Has indexed 959000 grams
# Has indexed 960000 grams
# Has indexed 961000 grams
# Has indexed 962000 grams
# Has indexed 963000 grams
# Has indexed 964000 grams
# Has indexed 965000 grams
# Has indexed 966000 grams
# Has indexed 967000 grams
# Has indexed 968000 grams
# Has indexed 969000 grams
# Has indexed 970000 grams
# Has indexed 971000 grams
# Has indexed 972000 grams
# Has indexed 973000 grams
# Has indexed 974000 grams
# Has indexed 975000 grams
# Has indexed 976000 grams
# Has indexed 977000 grams
# Has indexed 978000 grams
# Has indexed 979000 grams
# Has indexed 980000 grams
# Has indexed 981000 grams
# Has indexed 982000 grams
# Has indexed 983000 grams
# Has indexed 984000 grams
# Has indexed 985000 grams
# Has indexed 986000 grams
# Has indexed 987000 grams
# Has indexed 988000 grams
# Has indexed 989000 grams
# Has indexed 990000 grams
# Has indexed 991000 grams
# Has indexed 992000 grams
# Has indexed 993000 grams
# Has indexed 994000 grams
# Has indexed 995000 grams
# Has indexed 996000 grams
# Has indexed 997000 grams
# Has indexed 998000 grams
# Has indexed 999000 grams
# Has indexed 1000000 grams
# Has indexed 1001000 grams
# Has indexed 1002000 grams
# Has indexed 1003000 grams
# Has indexed 1004000 grams
# Has indexed 1005000 grams
# Has indexed 1006000 grams
# Has indexed 1007000 grams
# Has indexed 1008000 grams
# Has indexed 1009000 grams
# Has indexed 1010000 grams
# Has indexed 1011000 grams
# Has indexed 1012000 grams
# Has indexed 1013000 grams
# Has indexed 1014000 grams
# Has indexed 1015000 grams
# Has indexed 1016000 grams
# Has indexed 1017000 grams
# Has indexed 1018000 grams
# Has indexed 1019000 grams
# Has indexed 1020000 grams
# Has indexed 1021000 grams
# Has indexed 1022000 grams
# Has indexed 1023000 grams
# Has indexed 1024000 grams
# Has indexed 1025000 grams
# Has indexed 1026000 grams
# Has indexed 1027000 grams
# Has indexed 1028000 grams
# Has indexed 1029000 grams
# Has indexed 1030000 grams
# Has indexed 1031000 grams
# Has indexed 1032000 grams
# Has indexed 1033000 grams
# Has indexed 1034000 grams
# Has indexed 1035000 grams
# Has indexed 1036000 grams
# Has indexed 1037000 grams
# Has indexed 1038000 grams
# Has indexed 1039000 grams
# Has indexed 1040000 grams
# Has indexed 1041000 grams
# Has indexed 1042000 grams
# Has indexed 1043000 grams
# Has indexed 1044000 grams
# Has indexed 1045000 grams
# Has indexed 1046000 grams
# Has indexed 1047000 grams
# Has indexed 1048000 grams
# Has indexed 1049000 grams
# Has indexed 1050000 grams
# Has indexed 1051000 grams
# Has indexed 1052000 grams
# Has indexed 1053000 grams
# Has indexed 1054000 grams
# Has indexed 1055000 grams
# Has indexed 1056000 grams
# Has indexed 1057000 grams
# Has indexed 1058000 grams
# Has indexed 1059000 grams
# Has indexed 1060000 grams
# Has indexed 1061000 grams
# Has indexed 1062000 grams
# Has indexed 1063000 grams
# Has indexed 1064000 grams
# Has indexed 1065000 grams
# Has indexed 1066000 grams
# Has indexed 1067000 grams
# Has indexed 1068000 grams
# Has indexed 1069000 grams
# Has indexed 1070000 grams
# Has indexed 1071000 grams
# Has indexed 1072000 grams
# Has indexed 1073000 grams
# Has indexed 1074000 grams
# Has indexed 1075000 grams
# Has indexed 1076000 grams
# Has indexed 1077000 grams
# Has indexed 1078000 grams
# Has indexed 1079000 grams
# Has indexed 1080000 grams
# Has indexed 1081000 grams
# Has indexed 1082000 grams
# Has indexed 1083000 grams
# Has indexed 1084000 grams
# Has indexed 1085000 grams
# Has indexed 1086000 grams
# Has indexed 1087000 grams
# Has indexed 1088000 grams
# Has indexed 1089000 grams
# Has indexed 1090000 grams
# Has indexed 1091000 grams
# Has indexed 1092000 grams
# Has indexed 1093000 grams
# Has indexed 1094000 grams
# Has indexed 1095000 grams
# Has indexed 1096000 grams
# Has indexed 1097000 grams
# Has indexed 1098000 grams
# Has indexed 1099000 grams
# Has indexed 1100000 grams
# Has indexed 1101000 grams
# Has indexed 1102000 grams
# Has indexed 1103000 grams
# Has indexed 1104000 grams
# Has indexed 1105000 grams
# Has indexed 1106000 grams
# Has indexed 1107000 grams
# Has indexed 1108000 grams
# Has indexed 1109000 grams
# Has indexed 1110000 grams
# Has indexed 1111000 grams
# Has indexed 1112000 grams
# Has indexed 1113000 grams
# Has indexed 1114000 grams
# Has indexed 1115000 grams
# Has indexed 1116000 grams
# Has indexed 1117000 grams
# Has indexed 1118000 grams
# Has indexed 1119000 grams
# Has indexed 1120000 grams
# Has indexed 1121000 grams
# Has indexed 1122000 grams
# Has indexed 1123000 grams
# Has indexed 1124000 grams
# Has indexed 1125000 grams
# Has indexed 1126000 grams
# Has indexed 1127000 grams
# Has indexed 1128000 grams
# Has indexed 1129000 grams
# Has indexed 1130000 grams
# Has indexed 1131000 grams
# Has indexed 1132000 grams
# Has indexed 1133000 grams
# Has indexed 1134000 grams
# Has indexed 1135000 grams
# Has indexed 1136000 grams
# Has indexed 1137000 grams
# Has indexed 1138000 grams
# Has indexed 1139000 grams
# Has indexed 1140000 grams
# Has indexed 1141000 grams
# Has indexed 1142000 grams
# Has indexed 1143000 grams
# Has indexed 1144000 grams
# Has indexed 1145000 grams
# Has indexed 1146000 grams
# Has indexed 1147000 grams
# Has indexed 1148000 grams
# Has indexed 1149000 grams
# Has indexed 1150000 grams
# Has indexed 1151000 grams
# Has indexed 1152000 grams
# Has indexed 1153000 grams
# Has indexed 1154000 grams
# Has indexed 1155000 grams
# Has indexed 1156000 grams
# Has indexed 1157000 grams
# Has indexed 1158000 grams
# Has indexed 1159000 grams
# Has indexed 1160000 grams
# Has indexed 1161000 grams
# Has indexed 1162000 grams
# Has indexed 1163000 grams
# Has indexed 1164000 grams
# Has indexed 1165000 grams
# Has indexed 1166000 grams
# Has indexed 1167000 grams
# Has indexed 1168000 grams
# Has indexed 1169000 grams
# Has indexed 1170000 grams
# Has indexed 1171000 grams
